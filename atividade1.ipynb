# %% [markdown]
# Exercício 1 - Crie um programa que mostre na tela

# %%
a = "Eu estou aprendendo Python"
print(a)
# Out:
# Eu estou aprendendo Python

# %% [markdown]
# Exercício 2 - Crie um programa que mostre

# %%
nome = "Maria"
cidade = "Recife"
print("Meu nome é", nome)
print("Eu moro em", cidade)
# Out:
# Meu nome é Maria
# Eu moro em Recife

# %% [markdown]
# Exercício 3
# Crie duas variáveis: nome_do_aluno e idade_do_aluno.
# Depois mostre na tela algo assim:

# %%
nome_do_aluno = "Ana"
idade_do_aluno = 18
print("Meu nome é", nome_do_aluno, "e tenho", idade_do_aluno, "anos" )
# Out:
# Meu nome é Ana e tenho 18 anos

# %% [markdown]
# Exercício 4 (Desafio Extra)
# Crie três variáveis: cidade, estado e pais. E mostre:

# %%
cidade = "Salvador"
estado = "BA"
pais = "Brasil"
print("Eu moro em "+ cidade + " - " + estado + ", " + pais )
# Out:
# Eu moro em Salvador - BA, Brasil

# %% [markdown]
# Crie um programa que:
# 1. Pergunte o nome do aluno.
# 2. Pergunte a cidade onde ele mora.
# 3. Mostre a frase:

# %%
entrada = input("Digite o seu nome:")
cidade = input("Digite a cidade onde você mora?")
print("Olá,", entrada, "você mora em", cidade)
# Out:
# Digite o seu nome: walte
# Digite a cidade onde você mora? gyn
# Olá, walte você mora em gyn
