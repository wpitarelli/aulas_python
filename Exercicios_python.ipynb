# %%
#Exercicio 01
print("Eu estou aprendendo Python")
# Out:
# Eu estou aprendendo Python

# %%
#Exercicio 02
nome = "Maria"
cidade = "Goiânia"
print("Meu nome é", nome)
print("Eu moro em", cidade)
# Out:
# Meu nome é Maria
# Eu moro em Goiânia

# %%
#Exercicio 03
nome_aluno = "Ana"
idade_aluno = 18
print("Meu nome é", nome_aluno , "e tenho", idade_aluno, "anos")
# Out:
# Meu nome é Ana e tenho 18 anos

# %%
#Exercicio 04
cidade = "Salvador"
estado = "BA"
pais = "Brasil"
print("Eu moro em " + cidade + " - " + estado +", " + pais)
# Out:
# Eu moro em Salvador - BA, Brasil

# %%
#Exercicio 05
